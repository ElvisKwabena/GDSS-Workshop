# %%
### Step 1: Import necessary Libraries
import pandas as pd #Data transformation
import requests  #establishing connection with the web/api

# %%
url='https://api.coincap.io/v2/assets'

# %%
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#json files are called semi-structured data
responsedata=response.json()
responsedata
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19727053.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1270288769135.9464563551138816',
#    'volumeUsd24Hr': '13485431295.7623023243998786',
#    'priceUsd': '64393.2354790118147072',
#    'changePercent24Hr': '-0.2372270298605186',
#    'vwap24Hr': '65084.6368278846309041',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120221218.0299744500000000',
#    'maxSupply': None,
#    'marketCapUsd': '410510149174.9557454990811312',
#    'volumeUsd24Hr': '7626710175.6489000322980546',
#    'priceUsd': '3414.6231081488818045',
#    'changePercent24Hr': '-0.7050594297609693',
#    'vwap24Hr': '3458.7982051486844054',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '113224555138.6441000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '113284724948.4953089645110165',
#    'volumeUsd24Hr': '18340889942.9674102381338656',
#    'priceUsd': '1.0005314201480194',
#    'changePercent24Hr': '-0.0160476417654445',
#    'vwap24Hr': '1.0005706290306788',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '95197497973.9484471523228860',
#    'volumeUsd24Hr': '258463359.7957453169419630',
#    'priceUsd': '570.7244771118028945',
#    'changePercent24Hr': '-0.7733359048860728',
#    'vwap24Hr': '576.6544420648822098',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '464158693.5097646000000000',
#    'maxSupply': None,
#    'marketCapUsd': '72753605911.2140658196048293',
#    'volumeUsd24Hr': '796577628.4896392558375578',
#    'priceUsd': '156.7429565114534121',
#    'changePercent24Hr': '-2.2987416455419964',
#    'vwap24Hr': '159.9299239585070492',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '33784675807.9227680000000000',
#    'maxSupply': None,
#    'marketCapUsd': '33802537690.3006505772976797',
#    'volumeUsd24Hr': '1772112393.2420260835563009',
#    'priceUsd': '1.0005286977586949',
#    'changePercent24Hr': '0.0165230890626494',
#    'vwap24Hr': '1.0001189238530427',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'xrp',
#    'rank': '7',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '28660890032.1889447061554720',
#    'volumeUsd24Hr': '1520161745.4659864419648104',
#    'priceUsd': '0.6312411231046423',
#    'changePercent24Hr': '8.6118311871939847',
#    'vwap24Hr': '0.6082730435398212',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'dogecoin',
#    'rank': '8',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '145157396383.7052300000000000',
#    'maxSupply': None,
#    'marketCapUsd': '17749232860.2822913120397663',
#    'volumeUsd24Hr': '366125139.0186444862027070',
#    'priceUsd': '0.1222757730743836',
#    'changePercent24Hr': '-1.7066351511881411',
#    'vwap24Hr': '0.1245512753164206',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'cardano',
#    'rank': '9',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35887858445.5710000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '15821809853.5896114764627251',
#    'volumeUsd24Hr': '159159271.5359250008451503',
#    'priceUsd': '0.4408680411394739',
#    'changePercent24Hr': '0.7940998088190249',
#    'vwap24Hr': '0.4450224690882924',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'tron',
#    'rank': '10',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87104280445.1014100000000000',
#    'maxSupply': None,
#    'marketCapUsd': '11669830516.2956984887089180',
#    'volumeUsd24Hr': '141353548.2164535485851344',
#    'priceUsd': '0.1339753965782515',
#    'changePercent24Hr': '-0.1456938965546588',
#    'vwap24Hr': '0.1344334471546791',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'shiba-inu',
#    'rank': '11',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589270742857240.6000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '11040463969.0179548343400394',
#    'volumeUsd24Hr': '170776649.4840799836384646',
#    'priceUsd': '0.0000187358087990',
#    'changePercent24Hr': '-2.6803301834156733',
#    'vwap24Hr': '0.0000192134598562',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'avalanche',
#    'rank': '12',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '394707005.3898785000000000',
#    'maxSupply': '715748719.0000000000000000',
#    'marketCapUsd': '10901375423.1156873614523968',
#    'volumeUsd24Hr': '125006852.4426106756194927',
#    'priceUsd': '27.6189053506858080',
#    'changePercent24Hr': '-1.9566835125429555',
#    'vwap24Hr': '28.3114167353231417',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '13',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '154782.1938814600000000',
#    'maxSupply': None,
#    'marketCapUsd': '9967611392.0258225730646866',
#    'volumeUsd24Hr': '12061895.7224418158126785',
#    'priceUsd': '64397.6619149068362247',
#    'changePercent24Hr': '-0.2368613242785213',
#    'vwap24Hr': '65231.1184047095598826',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'polkadot',
#    'rank': '14',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1389132421.2735100000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8750438239.4640493733472349',
#    'volumeUsd24Hr': '101760382.3009511911618162',
#    'priceUsd': '6.2992110078619727',
#    'changePercent24Hr': '-0.8033830375312342',
#    'vwap24Hr': '6.4184179227113108',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'chainlink',
#    'rank': '15',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '608099970.4527867000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8423114657.8076637049823140',
#    'volumeUsd24Hr': '175538977.8575059311458315',
#    'priceUsd': '13.8515294640384136',
#    'changePercent24Hr': '-2.5490601931540003',
#    'vwap24Hr': '14.2346070937993461',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'bitcoin-cash',
#    'rank': '16',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19734187.5000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '7459315174.6169790578130000',
#    'volumeUsd24Hr': '127344767.0575933207968391',
#    'priceUsd': '377.9894750983276640',
#    'changePercent24Hr': '-1.8062401047804466',
#    'vwap24Hr': '384.1740559049206485',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'near-protocol',
#    'rank': '17',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1102754809.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '6784786477.7096827829985176',
#    'volumeUsd24Hr': '124238799.8007175786386176',
#    'priceUsd': '6.1525793606488664',
#    'changePercent24Hr': '-0.5918575257607965',
#    'vwap24Hr': '6.2394153770700658',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'polygon',
#    'rank': '18',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9897683258.6191540000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5397414141.2198977357417283',
#    'volumeUsd24Hr': '65761891.2016359801787012',
#    'priceUsd': '0.5453209604903948',
#    'changePercent24Hr': '0.2373777429741490',
#    'vwap24Hr': '0.5509879377962893',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'litecoin',
#    'rank': '19',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74761249.8575049000000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '5356107597.1693053032390221',
#    'volumeUsd24Hr': '165973046.4653911183947292',
#    'priceUsd': '71.6428311107433020',
#    'changePercent24Hr': '-2.1136835445971587',
#    'vwap24Hr': '72.8450136385974220',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'multi-collateral-dai',
#    'rank': '20',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5340449599.8045813191925200',
#    'volumeUsd24Hr': '44491331.2981773306175750',
#    'priceUsd': '0.9986089844975935',
#    'changePercent24Hr': '-0.0352128937152373',
#    'vwap24Hr': '0.9998063334624374',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'unus-sed-leo',
#    'rank': '21',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '925968078.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5256063285.4916300983432576',
#    'volumeUsd24Hr': '699589.3099699718636750',
#    'priceUsd': '5.6762899340283404',
#    'changePercent24Hr': '-3.0007986851767072',
#    'vwap24Hr': '5.8147248590376574',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'internet-computer',
#    'rank': '22',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '466715078.7336353000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4822267034.6780488425384413',
#    'volumeUsd24Hr': '87000555.9871971424299291',
#    'priceUsd': '10.3323574797767015',
#    'changePercent24Hr': '6.6554182458285955',
#    'vwap24Hr': '10.0294077310372519',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'uniswap',
#    'rank': '23',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '600034294.7100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4805799441.5739473207589911',
#    'volumeUsd24Hr': '110289223.6903162029321305',
#    'priceUsd': '8.0092079468501340',
#    'changePercent24Hr': '-1.9118554213124619',
#    'vwap24Hr': '8.1637226092782809',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'fetch',
#    'rank': '24',
#    'symbol': 'FET',
#    'name': 'Artificial Superintelligence Alliance',
#    'supply': '2520000000.0000000000000000',
#    'maxSupply': '2630547141.0000000000000000',
#    'marketCapUsd': '3704917341.2091674400000000',
#    'volumeUsd24Hr': '124107619.7650226182410815',
#    'priceUsd': '1.4702052941306220',
#    'changePercent24Hr': '3.8389315520416851',
#    'vwap24Hr': '1.4896855447682405',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'ethereum-classic',
#    'rank': '25',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '147958268.1461534200000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '3413788047.8368082789356143',
#    'volumeUsd24Hr': '83628140.8980537218680876',
#    'priceUsd': '23.0726412968328532',
#    'changePercent24Hr': '-2.2746381203717485',
#    'vwap24Hr': '23.5430773874588967',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'stellar',
#    'rank': '26',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '29309405866.8075830000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '3208100362.8843857161856783',
#    'volumeUsd24Hr': '74434987.0000808512240178',
#    'priceUsd': '0.1094563423585978',
#    'changePercent24Hr': '2.9098086286166712',
#    'vwap24Hr': '0.1091239824442348',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'monero',
#    'rank': '27',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18446744.0737095500000000',
#    'maxSupply': None,
#    'marketCapUsd': '2943452128.8542324951030229',
#    'volumeUsd24Hr': '57584058.0003155357826163',
#    'priceUsd': '159.5648596355421041',
#    'changePercent24Hr': '-1.9850070265715089',
#    'vwap24Hr': '161.5974418154715359',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'stacks',
#    'rank': '28',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1474727471.2246230000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '2799253860.8792405068966459',
#    'volumeUsd24Hr': '20264773.6912234569154591',
#    'priceUsd': '1.8981499399036233',
#    'changePercent24Hr': '0.6235630846242588',
#    'vwap24Hr': '1.9275721776178502',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'maker',
#    'rank': '29',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '930401.8833898900000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '2683988969.5373769299761336',
#    'volumeUsd24Hr': '68200502.8743340846000039',
#    'priceUsd': '2884.7630442861395914',
#    'changePercent24Hr': '-4.5203685100763424',
#    'vwap24Hr': '2979.6814680787303253',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'filecoin',
#    'rank': '30',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '571512377.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2641842838.0076650053403258',
#    'volumeUsd24Hr': '107214308.8425690217802615',
#    'priceUsd': '4.6225470249223754',
#    'changePercent24Hr': '1.9392029502980211',
#    'vwap24Hr': '4.6069982355067116',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'render-token',
#    'rank': '31',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '2570209190.3067508414066558',
#    'volumeUsd24Hr': '8984700.3842237567697965',
#    'priceUsd': '6.9537656417778662',
#    'changePercent24Hr': '6.6320718643260294',
#    'vwap24Hr': '6.6872342414986347',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'okb',
#    'rank': '32',
#    'symbol': 'OKB',
#    'name': 'OKB',
#    'supply': '60000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2569119202.3405233660000000',
#    'volumeUsd24Hr': '799767.5439470770974259',
#    'priceUsd': '42.8186533723420561',
#    'changePercent24Hr': '0.0656829178447214',
#    'vwap24Hr': '42.7774540346597778',
#    'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c'},
#   {'id': 'vechain',
#    'rank': '33',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '80985041177.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '2554594159.0094396404946751',
#    'volumeUsd24Hr': '19768687.9454463126860039',
#    'priceUsd': '0.0315440249443863',
#    'changePercent24Hr': '-0.6115163207596494',
#    'vwap24Hr': '0.0319157886342171',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'crypto-com-coin',
#    'rank': '34',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '2356566230.2703988645437868',
#    'volumeUsd24Hr': '3401879.1961201340860883',
#    'priceUsd': '0.0932812790667429',
#    'changePercent24Hr': '-1.2486662153825939',
#    'vwap24Hr': '0.0944435607559414',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'arweave',
#    'rank': '35',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65652466.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '2042085526.3591267752978084',
#    'volumeUsd24Hr': '62213587.2248202907873070',
#    'priceUsd': '31.1044755936376674',
#    'changePercent24Hr': '6.2540973269694115',
#    'vwap24Hr': '31.3435199809676967',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'the-graph',
#    'rank': '36',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9548531509.1654740000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2027359754.6545989515634336',
#    'volumeUsd24Hr': '25821135.5260023821590010',
#    'priceUsd': '0.2123216279601288',
#    'changePercent24Hr': '-0.3419571893097021',
#    'vwap24Hr': '0.2152018106633911',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'injective-protocol',
#    'rank': '37',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1898872417.8224924574424292',
#    'volumeUsd24Hr': '73434976.2050174967968997',
#    'priceUsd': '26.0099719158244005',
#    'changePercent24Hr': '4.4945705464370824',
#    'vwap24Hr': '25.8474059846541582',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'lido-dao',
#    'rank': '38',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '892898085.0833479000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1757342336.9677713271901099',
#    'volumeUsd24Hr': '9476648.7073738875870640',
#    'priceUsd': '1.9681331680801304',
#    'changePercent24Hr': '8.4205669520495235',
#    'vwap24Hr': '1.9269099736087263',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'cosmos',
#    'rank': '39',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1630331459.2755548558292989',
#    'volumeUsd24Hr': '51997695.4522859075484203',
#    'priceUsd': '6.5619257579038189',
#    'changePercent24Hr': '-0.8066430176277070',
#    'vwap24Hr': '6.6576698373260649',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'theta',
#    'rank': '40',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '1501897350.9276032000000000',
#    'volumeUsd24Hr': '12302033.2363868511891935',
#    'priceUsd': '1.5018973509276032',
#    'changePercent24Hr': '-1.2889627713744612',
#    'vwap24Hr': '1.5387887872577834',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'aave',
#    'rank': '41',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14875116.5475874600000000',
#    'maxSupply': None,
#    'marketCapUsd': '1463876578.5397032970569861',
#    'volumeUsd24Hr': '40652443.8100775837085600',
#    'priceUsd': '98.4110997622485191',
#    'changePercent24Hr': '-1.7051318430191580',
#    'vwap24Hr': '100.3969686215806101',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'thorchain',
#    'rank': '42',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '336838590.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1455501282.0633133048082520',
#    'volumeUsd24Hr': '63814137.5374584088104525',
#    'priceUsd': '4.3210645254847828',
#    'changePercent24Hr': '5.7497037713173759',
#    'vwap24Hr': '4.2269307465648527',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'fantom',
#    'rank': '43',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1449747559.5336390804306382',
#    'volumeUsd24Hr': '40924807.8130775241497880',
#    'priceUsd': '0.5170957148780541',
#    'changePercent24Hr': '-0.6813222469787138',
#    'vwap24Hr': '0.5223242625716844',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'algorand',
#    'rank': '44',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8229247227.3568320000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '1288267726.9745467663751202',
#    'volumeUsd24Hr': '25683113.5340365174612872',
#    'priceUsd': '0.1565474570616744',
#    'changePercent24Hr': '-1.3346488556964934',
#    'vwap24Hr': '0.1589456854380118',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'hedera-hashgraph',
#    'rank': '45',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '1130607248.5950546918672824',
#    'volumeUsd24Hr': '16869783.7425009489659570',
#    'priceUsd': '0.0762236799729458',
#    'changePercent24Hr': '-0.4569741919393447',
#    'vwap24Hr': '0.0771912030393528',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'flow',
#    'rank': '46',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1511780104.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '936638531.7154896633963248',
#    'volumeUsd24Hr': '15332457.7979023277183488',
#    'priceUsd': '0.6195600333919262',
#    'changePercent24Hr': '0.1629599418876685',
#    'vwap24Hr': '0.6235259930701066',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'quant',
#    'rank': '47',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '934300190.9953027755431802',
#    'volumeUsd24Hr': '3858838.9118844766624568',
#    'priceUsd': '77.3892542847614829',
#    'changePercent24Hr': '-2.4178059109475985',
#    'vwap24Hr': '79.4322466761652988',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'kucoin-token',
#    'rank': '48',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '95540492.2885607500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '923375079.2913738383202280',
#    'volumeUsd24Hr': '485210.7860321475836629',
#    'priceUsd': '9.6647511141402329',
#    'changePercent24Hr': '-0.6831625314518163',
#    'vwap24Hr': '9.7144219463670606',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'eos',
#    'rank': '49',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1502354006.8587000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '909312294.6779586756499637',
#    'volumeUsd24Hr': '41453825.9335066904298844',
#    'priceUsd': '0.6052583415937078',
#    'changePercent24Hr': '0.7550602829231808',
#    'vwap24Hr': '0.6101997373498913',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'axie-infinity',
#    'rank': '50',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '147949467.6321948000000000',
#    'maxSupply': None,
#    'marketCapUsd': '899102784.5977283542155523',
#    'volumeUsd24Hr': '17565120.8996653407995571',
#    'priceUsd': '6.0770937468522363',
#    'changePercent24Hr': '0.9675583112426962',
#    'vwap24Hr': '6.1258282060437083',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'bitcoin-sv',
#    'rank': '51',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19730137.5000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '898929479.3377308162730425',
#    'volumeUsd24Hr': '6924119.2552710809345915',
#    'priceUsd': '45.5612374388029894',
#    'changePercent24Hr': '0.1094893856896071',
#    'vwap24Hr': '46.0166217510335778',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'elrond-egld',
#    'rank': '52',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '895082613.6169165778514594',
#    'volumeUsd24Hr': '16705689.4956098994685859',
#    'priceUsd': '37.0104994095937980',
#    'changePercent24Hr': '1.7014746169906915',
#    'vwap24Hr': '36.9180395775239492',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'akash-network',
#    'rank': '53',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '244666729.1903120000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '875275702.9391630578864251',
#    'volumeUsd24Hr': '6233874.3617672587973524',
#    'priceUsd': '3.5774202149828760',
#    'changePercent24Hr': '-3.5682827073758562',
#    'vwap24Hr': '3.6733750419102250',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'gala',
#    'rank': '54',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '32891832126.2793900000000000',
#    'maxSupply': None,
#    'marketCapUsd': '848153744.7243857395395013',
#    'volumeUsd24Hr': '27885853.1286741785362357',
#    'priceUsd': '0.0257861508434108',
#    'changePercent24Hr': '0.3300148811050231',
#    'vwap24Hr': '0.0256080288377599',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'neo',
#    'rank': '55',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '823233999.0825125282594388',
#    'volumeUsd24Hr': '12135759.2576820552567393',
#    'priceUsd': '11.6706498734365548',
#    'changePercent24Hr': '2.2365893910810345',
#    'vwap24Hr': '11.6800893091031246',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'tezos',
#    'rank': '56',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '989854694.0353730000000000',
#    'maxSupply': None,
#    'marketCapUsd': '803712598.2324999294710888',
#    'volumeUsd24Hr': '22048346.6407401829524178',
#    'priceUsd': '0.8119500802243797',
#    'changePercent24Hr': '-1.0198377937980283',
#    'vwap24Hr': '0.8239306893558577',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'the-sandbox',
#    'rank': '57',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2281231926.2233224000000000',
#    'maxSupply': None,
#    'marketCapUsd': '769577611.0289145891577686',
#    'volumeUsd24Hr': '15223020.7586427196022818',
#    'priceUsd': '0.3373517625202552',
#    'changePercent24Hr': '-0.1775690294511218',
#    'vwap24Hr': '0.3401600786231641',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'nexo',
#    'rank': '58',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '739032590.8926503696702313',
#    'volumeUsd24Hr': '314612.7404335202077103',
#    'priceUsd': '1.3197010292427483',
#    'changePercent24Hr': '-1.6105068915797840',
#    'vwap24Hr': '1.2786211087902287',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'conflux-network',
#    'rank': '59',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '4234642458.6300000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '734590755.2112616970192181',
#    'volumeUsd24Hr': '12839572.1286258885557217',
#    'priceUsd': '0.1734717304678700',
#    'changePercent24Hr': '-0.9857748273180078',
#    'vwap24Hr': '0.1746377531773199',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'ecash',
#    'rank': '60',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19730417173091.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '725549128.7603823360303463',
#    'volumeUsd24Hr': '6256048.6632411357903520',
#    'priceUsd': '0.0000367731266093',
#    'changePercent24Hr': '-1.5706636191086290',
#    'vwap24Hr': '0.0000370675326997',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'pendle',
#    'rank': '61',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '155658484.6409074700000000',
#    'maxSupply': None,
#    'marketCapUsd': '722857978.7238497109720574',
#    'volumeUsd24Hr': '2898732.7628571895279604',
#    'priceUsd': '4.6438713597362150',
#    'changePercent24Hr': '2.3719985346197489',
#    'vwap24Hr': '4.6581117856753188',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'gatetoken',
#    'rank': '62',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '93236970.8431050300000000',
#    'maxSupply': None,
#    'marketCapUsd': '715592410.2796947541155672',
#    'volumeUsd24Hr': '2473495.8443323169446125',
#    'priceUsd': '7.6749856179246899',
#    'changePercent24Hr': '-0.1551050294316556',
#    'vwap24Hr': '7.7426183902660921',
#    'explorer': None},
#   {'id': 'decentraland',
#    'rank': '63',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '684737501.2178501303546389',
#    'volumeUsd24Hr': '14844882.8665730864002442',
#    'priceUsd': '0.3588169434463974',
#    'changePercent24Hr': '-0.6838199506197588',
#    'vwap24Hr': '0.3645397165810586',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'helium',
#    'rank': '64',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': None,
#    'marketCapUsd': '681834788.1204188515691822',
#    'volumeUsd24Hr': '6739599.9312648425869607',
#    'priceUsd': '4.2382776413161405',
#    'changePercent24Hr': '10.0455869137388718',
#    'vwap24Hr': '4.2777900305615019',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'gnosis-gno',
#    'rank': '65',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '674508693.0368130078564072',
#    'volumeUsd24Hr': '6723637.5659606456561489',
#    'priceUsd': '260.4695005679718194',
#    'changePercent24Hr': '-4.9542900661957020',
#    'vwap24Hr': '264.4806709621731684',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'chiliz',
#    'rank': '66',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8919064798.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '650100138.4203793142821082',
#    'volumeUsd24Hr': '18916845.4601233201630917',
#    'priceUsd': '0.0728888233401059',
#    'changePercent24Hr': '-0.8429426403354477',
#    'vwap24Hr': '0.0737927793939095',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'mantra-dao',
#    'rank': '67',
#    'symbol': 'OM',
#    'name': 'MANTRA DAO',
#    'supply': '500205033.1781248500000000',
#    'maxSupply': '888888888.0000000000000000',
#    'marketCapUsd': '649649655.9388512591359609',
#    'volumeUsd24Hr': '17890492.6864888778522180',
#    'priceUsd': '1.2987667313365650',
#    'changePercent24Hr': '0.4773404914038352',
#    'vwap24Hr': '1.2863111033840068',
#    'explorer': 'https://etherscan.io/token/0x3593d125a4f7849a1b059e64f4517a86dd60c95d'},
#   {'id': 'mina',
#    'rank': '68',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1133271374.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '633980247.5441730875616301',
#    'volumeUsd24Hr': '8864729.7559132889007266',
#    'priceUsd': '0.5594249194140804',
#    'changePercent24Hr': '2.7147874373078221',
#    'vwap24Hr': '0.5604656390591055',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'oasis-network',
#    'rank': '69',
#    'symbol': 'ROSE',
#    'name': 'Oasis',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '609874778.7310697401492816',
#    'volumeUsd24Hr': '8624002.7800787354109393',
#    'priceUsd': '0.0908416929807316',
#    'changePercent24Hr': '-1.4642112283232831',
#    'vwap24Hr': '0.0928548648025512',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'dexe',
#    'rank': '70',
#    'symbol': 'DEXE',
#    'name': 'DeXe',
#    'supply': '57103225.3406123900000000',
#    'maxSupply': '98942301.0000000000000000',
#    'marketCapUsd': '594480034.6185089614473402',
#    'volumeUsd24Hr': '489894.9102168404987209',
#    'priceUsd': '10.4106209600687610',
#    'changePercent24Hr': '1.1898031716654275',
#    'vwap24Hr': '10.4064400122726974',
#    'explorer': 'https://etherscan.io/token/0xde4EE8057785A7e8e800Db58F9784845A5C2Cbd6'},
#   {'id': 'klaytn',
#    'rank': '71',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3704162451.8202960000000000',
#    'maxSupply': None,
#    'marketCapUsd': '586219234.6636597383641102',
#    'volumeUsd24Hr': '2511438.9783960017356448',
#    'priceUsd': '0.1582595910110747',
#    'changePercent24Hr': '0.2116304559367402',
#    'vwap24Hr': '0.1595016611964676',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'iota',
#    'rank': '72',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3344331631.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '582279485.3028940289901274',
#    'volumeUsd24Hr': '4807497.4236788875396437',
#    'priceUsd': '0.1741093735757254',
#    'changePercent24Hr': '1.8534456014488994',
#    'vwap24Hr': '0.1731404154717421',
#    'explorer': 'https://thetangle.org/'},
#   {'id': 'livepeer',
#    'rank': '73',
#    'symbol': 'LPT',
#    'name': 'Livepeer',
#    'supply': '33364596.7940064300000000',
#    'maxSupply': None,
#    'marketCapUsd': '575665238.8060190080322879',
#    'volumeUsd24Hr': '24603735.6155489588776698',
#    'priceUsd': '17.2537747828989414',
#    'changePercent24Hr': '11.6014281585550615',
#    'vwap24Hr': '16.5855021504603165',
#    'explorer': 'https://explorer.livepeer.org/'},
#   {'id': '1inch',
#    'rank': '74',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1254328963.2140850000000000',
#    'maxSupply': None,
#    'marketCapUsd': '538126327.9302289609066651',
#    'volumeUsd24Hr': '9380133.6001501308994403',
#    'priceUsd': '0.4290153091509083',
#    'changePercent24Hr': '1.0448835660108163',
#    'vwap24Hr': '0.4301945596124855',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'pancakeswap',
#    'rank': '75',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '267428535.9351197200000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '536718433.5780093245923715',
#    'volumeUsd24Hr': '7900209.0332324302698155',
#    'priceUsd': '2.0069602209848745',
#    'changePercent24Hr': '-1.4415323178782196',
#    'vwap24Hr': '2.0421320017053662',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'nervos-network',
#    'rank': '76',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '44572559154.3087300000000000',
#    'maxSupply': None,
#    'marketCapUsd': '533217285.8060615419528891',
#    'volumeUsd24Hr': '14197863.8384470854916882',
#    'priceUsd': '0.0119629048886352',
#    'changePercent24Hr': '-2.8750195139990468',
#    'vwap24Hr': '0.0122804080979612',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'aioz-network',
#    'rank': '77',
#    'symbol': 'AIOZ',
#    'name': 'AIOZ Network',
#    'supply': '1108119914.4942179000000000',
#    'maxSupply': None,
#    'marketCapUsd': '530446775.9103336309115706',
#    'volumeUsd24Hr': '2829364.5946645440073387',
#    'priceUsd': '0.4786907707118023',
#    'changePercent24Hr': '-1.3553714906348351',
#    'vwap24Hr': '0.5009948571317864',
#    'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18'},
#   {'id': 'zcash',
#    'rank': '78',
#    'symbol': 'ZEC',
#    'name': 'Zcash',
#    'supply': '16328268.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '514409433.3704058660026306',
#    'volumeUsd24Hr': '69978159.2813448818383633',
#    'priceUsd': '31.5042238247337683',
#    'changePercent24Hr': '6.7374157136594851',
#    'vwap24Hr': '30.9528474199912992',
#    'explorer': 'https://explorer.zcha.in/'},
#   {'id': 'raydium',
#    'rank': '79',
#    'symbol': 'RAY',
#    'name': 'Raydium',
#    'supply': '263557747.0601180000000000',
#    'maxSupply': None,
#    'marketCapUsd': '510153082.6897173893306768',
#    'volumeUsd24Hr': '7259474.8382344907510388',
#    'priceUsd': '1.9356406266948038',
#    'changePercent24Hr': '-5.1239030766896351',
#    'vwap24Hr': '1.9979719176767137',
#    'explorer': 'https://explorer.solana.com/address/4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R'},
#   {'id': 'wemix',
#    'rank': '80',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '407994984.1167940500000000',
#    'maxSupply': '590000000.0000000000000000',
#    'marketCapUsd': '504254077.1467084171530860',
#    'volumeUsd24Hr': '3536160.0734591580512364',
#    'priceUsd': '1.2359320500919661',
#    'changePercent24Hr': '-1.5536930749002735',
#    'vwap24Hr': '1.2614275843443914',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'trueusd',
#    'rank': '81',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '495201532.6100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '494766848.4674293215104153',
#    'volumeUsd24Hr': '8999406.9395019448503475',
#    'priceUsd': '0.9991222075984304',
#    'changePercent24Hr': '-0.0247564648528550',
#    'vwap24Hr': '0.9990765573882192',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'ftx-token',
#    'rank': '82',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': None,
#    'marketCapUsd': '490815004.4739952307394289',
#    'volumeUsd24Hr': '26627042.7234178459028967',
#    'priceUsd': '1.4923147191414232',
#    'changePercent24Hr': '-3.4092210167806608',
#    'vwap24Hr': '1.5445229412728620',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'theta-fuel',
#    'rank': '83',
#    'symbol': 'TFUEL',
#    'name': 'Theta Fuel',
#    'supply': '6617018105.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '474838364.0827134141811825',
#    'volumeUsd24Hr': '1204777.8552086812968864',
#    'priceUsd': '0.0717601730187065',
#    'changePercent24Hr': '-1.0258844192404521',
#    'vwap24Hr': '0.0726545862892721',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'kava',
#    'rank': '84',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082855129.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '454502112.3638999696970207',
#    'volumeUsd24Hr': '3278174.2903654145951568',
#    'priceUsd': '0.4197256864670583',
#    'changePercent24Hr': '-0.6081576933658491',
#    'vwap24Hr': '0.4248851378507441',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'synthetix-network-token',
#    'rank': '85',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '452698001.4070251522427124',
#    'volumeUsd24Hr': '12445733.9250865635581547',
#    'priceUsd': '1.9369516022539938',
#    'changePercent24Hr': '2.0044607306288583',
#    'vwap24Hr': '1.9296057658128500',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'iotex',
#    'rank': '86',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378929.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '446626529.9066651291923078',
#    'volumeUsd24Hr': '9899889.5706013441814384',
#    'priceUsd': '0.0473052223902182',
#    'changePercent24Hr': '4.2157530047333945',
#    'vwap24Hr': '0.0467878846881011',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'trust-wallet-token',
#    'rank': '87',
#    'symbol': 'TWT',
#    'name': 'Trust Wallet Token',
#    'supply': '416649900.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '445463047.0694448489912300',
#    'volumeUsd24Hr': '2175729.7958856853789363',
#    'priceUsd': '1.0691543357371377',
#    'changePercent24Hr': '-0.1090716004493681',
#    'vwap24Hr': '1.0824098106457952',
#    'explorer': 'https://explorer.binance.org/asset/TWT-8C2'},
#   {'id': 'compound',
#    'rank': '88',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8359756.4835560100000000',
#    'maxSupply': None,
#    'marketCapUsd': '425696066.4848706925397761',
#    'volumeUsd24Hr': '16503750.4279432345334797',
#    'priceUsd': '50.9220654121005351',
#    'changePercent24Hr': '-1.3676233639831199',
#    'vwap24Hr': '51.6801454566687823',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'fei-protocol',
#    'rank': '89',
#    'symbol': 'FEI',
#    'name': 'Fei Protocol',
#    'supply': '424996177.7889055600000000',
#    'maxSupply': None,
#    'marketCapUsd': '407851915.2815282004837372',
#    'volumeUsd24Hr': '196889.4936866094560426',
#    'priceUsd': '0.9596601960126501',
#    'changePercent24Hr': '-0.0058808665794001',
#    'vwap24Hr': '0.9592935722353396',
#    'explorer': 'https://etherscan.io/token/0x956F47F50A910163D8BF957Cf5846D573E7f87CA'},
#   {'id': 'xinfin-network',
#    'rank': '90',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '399933294.9662393146421760',
#    'volumeUsd24Hr': '1118028.9909788211745101',
#    'priceUsd': '0.0325326402044138',
#    'changePercent24Hr': '5.1922313670680640',
#    'vwap24Hr': '0.0316396693671551',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'wootrade',
#    'rank': '91',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1915683924.5056205000000000',
#    'maxSupply': None,
#    'marketCapUsd': '396021895.7974260794929488',
#    'volumeUsd24Hr': '10645672.1339085171477352',
#    'priceUsd': '0.2067261152695778',
#    'changePercent24Hr': '2.2223478035977647',
#    'vwap24Hr': '0.2070127357850256',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'aragon',
#    'rank': '92',
#    'symbol': 'ANT',
#    'name': 'Aragon',
#    'supply': '43191429.8753035100000000',
#    'maxSupply': None,
#    'marketCapUsd': '372396090.8667597853342947',
#    'volumeUsd24Hr': '1661641.7397403919772931',
#    'priceUsd': '8.6219903333113008',
#    'changePercent24Hr': '-0.5910773914559879',
#    'vwap24Hr': '8.6914594364604320',
#    'explorer': 'https://etherscan.io/token/Aragon'},
#   {'id': 'golem-network-tokens',
#    'rank': '93',
#    'symbol': 'GLM',
#    'name': 'Golem',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '348060233.4615666000000000',
#    'volumeUsd24Hr': '238345.3335117084578030',
#    'priceUsd': '0.3480602334615666',
#    'changePercent24Hr': '-1.7235924589503044',
#    'vwap24Hr': '0.3513858138741970',
#    'explorer': 'https://etherscan.io/token/Golem'},
#   {'id': 'kusama',
#    'rank': '94',
#    'symbol': 'KSM',
#    'name': 'Kusama',
#    'supply': '15218403.6367260500000000',
#    'maxSupply': None,
#    'marketCapUsd': '347381506.6007431455904100',
#    'volumeUsd24Hr': '8568955.7251412177076522',
#    'priceUsd': '22.8264090566253155',
#    'changePercent24Hr': '-1.9789731314662237',
#    'vwap24Hr': '23.1513012736272399',
#    'explorer': 'https://kusama.subscan.io/'},
#   {'id': 'curve-dao-token',
#    'rank': '95',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1187655008.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '339900811.5992808771178944',
#    'volumeUsd24Hr': '10791468.4159893029547564',
#    'priceUsd': '0.2861949045048618',
#    'changePercent24Hr': '-0.5319356463068926',
#    'vwap24Hr': '0.2906207376856104',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'dash',
#    'rank': '96',
#    'symbol': 'DASH',
#    'name': 'Dash',
#    'supply': '11880613.3370014800000000',
#    'maxSupply': '18900000.0000000000000000',
#    'marketCapUsd': '331414236.5620786594136391',
#    'volumeUsd24Hr': '22150225.9887299335676752',
#    'priceUsd': '27.8953810852431561',
#    'changePercent24Hr': '-0.3604848763017296',
#    'vwap24Hr': '28.0580421497407774',
#    'explorer': 'https://explorer.dash.org'},
#   {'id': 'enjin-coin',
#    'rank': '97',
#    'symbol': 'ENJ',
#    'name': 'Enjin Coin',
#    'supply': '1652988613.4919078000000000',
#    'maxSupply': None,
#    'marketCapUsd': '330368466.8563735001388298',
#    'volumeUsd24Hr': '4511666.0167377883533306',
#    'priceUsd': '0.1998613082751225',
#    'changePercent24Hr': '4.6352598349527086',
#    'vwap24Hr': '0.1971043206957903',
#    'explorer': 'https://etherscan.io/token/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#   {'id': 'zilliqa',
#    'rank': '98',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '18704789775.0079500000000000',
#    'maxSupply': None,
#    'marketCapUsd': '328451986.0402935354013514',
#    'volumeUsd24Hr': '8424227.3622998077179253',
#    'priceUsd': '0.0175597796067801',
#    'changePercent24Hr': '-0.8866041610788603',
#    'vwap24Hr': '0.0177102006695673',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'superfarm',
#    'rank': '99',
#    'symbol': 'SUPER',
#    'name': 'SuperVerse',
#    'supply': '487776093.4169172600000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '325347551.2976490360494208',
#    'volumeUsd24Hr': '4573496.6844223466779947',
#    'priceUsd': '0.6670018389350715',
#    'changePercent24Hr': '2.2799143548536977',
#    'vwap24Hr': '0.6744763229320383',
#    'explorer': 'https://etherscan.io/token/0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55'},
#   {'id': 'celo',
#    'rank': '100',
#    'symbol': 'CELO',
#    'name': 'Celo',
#    'supply': '542396781.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '317421115.3077281916126957',
#    'volumeUsd24Hr': '1772916.1617641415291227',
#    'priceUsd': '0.5852193936743297',
#    'changePercent24Hr': '1.4455725930905876',
#    'vwap24Hr': '0.5818626629581858',
#    'explorer': 'https://explorer.celo.org/blocks'}],
#  'timestamp': 1721254036975}

# %%
### Transformation (Restructuring and data cleaning)

# %%
df=pd.json_normalize(responsedata,"data")
df.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19727053.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120221218.0299744500000000
# 2        tether    3   USDT    Tether  113224555138.6441000000000000
# 3  binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4        solana    5    SOL    Solana     464158693.5097646000000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1270288769135.9464563551138816
# 1                        None   410510149174.9557454990811312
# 2                        None   113284724948.4953089645110165
# 3  166801148.0000000000000000    95197497973.9484471523228860
# 4                        None    72753605911.2140658196048293
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0  13485431295.7623023243998786  64393.2354790118147072  -0.2372270298605186
# 1   7626710175.6489000322980546   3414.6231081488818045  -0.7050594297609693
# 2  18340889942.9674102381338656      1.0005314201480194  -0.0160476417654445
# 3    258463359.7957453169419630    570.7244771118028945  -0.7733359048860728
# 4    796577628.4896392558375578    156.7429565114534121  -2.2987416455419964
#
#                  vwap24Hr                                           explorer
# 0  65084.6368278846309041                           https://blockchain.info/
# 1   3458.7982051486844054                              https://etherscan.io/
# 2      1.0005706290306788             https://www.omniexplorer.info/asset/31
# 3    576.6544420648822098  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4    159.9299239585070492                       https://explorer.solana.com/

# %%
df.info() #full description of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    object
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    object
#  5   maxSupply          37 non-null     object
#  6   marketCapUsd       100 non-null    object
#  7   volumeUsd24Hr      100 non-null    object
#  8   priceUsd           100 non-null    object
#  9   changePercent24Hr  100 non-null    object
#  10  vwap24Hr           100 non-null    object
#  11  explorer           99 non-null     object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %%
#### Step 3: Converting Categorical Data to Numerical Data
def convert_columns_to_datatypes(data,column_datatypes):
    for column, datatype in column_datatypes.items():
        if column in data.columns:
            data[column]=data[column].astype(datatype)
    return data

# %%
column_datatypes={
    'rank':int,
    'supply':float,
    'maxSupply':float,
'marketCapUsd':float,
'volumeUsd24Hr':float,
'priceUsd' :float,
'changePercent24Hr':float,
'vwap24Hr':float
}

df=convert_columns_to_datatypes(df,column_datatypes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int32
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          37 non-null     float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           100 non-null    float64
#  11  explorer           99 non-null     object
# dtypes: float64(7), int32(1), object(4)
# memory usage: 9.1+ KB

# %%
#### Step 4: Dealing with missing values
df['maxSupply']=df['maxSupply'].fillna(0)
df['explorer']=df['explorer'].fillna('not available')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int32
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          100 non-null    float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           100 non-null    float64
#  11  explorer           100 non-null    object
# dtypes: float64(7), int32(1), object(4)
# memory usage: 9.1+ KB

# %%
#### Step 5: Round number to 2 decimal

# %%
def round_to_two_decimal_places(number):
    return round(number, 2)

# %%
selected_columns=["supply","maxSupply","marketCapUsd","priceUsd","changePercent24Hr","vwap24Hr"]
df[selected_columns]=df[selected_columns].applymap(round_to_two_decimal_places)
df.head()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10844\1493471381.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[selected_columns]=df[selected_columns].applymap(round_to_two_decimal_places)
#              id  rank symbol      name        supply    maxSupply  \
# 0       bitcoin     1    BTC   Bitcoin  1.972705e+07   21000000.0
# 1      ethereum     2    ETH  Ethereum  1.202212e+08          0.0
# 2        tether     3   USDT    Tether  1.132246e+11          0.0
# 3  binance-coin     4    BNB       BNB  1.668011e+08  166801148.0
# 4        solana     5    SOL    Solana  4.641587e+08          0.0
#
#    marketCapUsd  volumeUsd24Hr  priceUsd  changePercent24Hr  vwap24Hr  \
# 0  1.270289e+12   1.348543e+10  64393.24              -0.24  65084.64
# 1  4.105101e+11   7.626710e+09   3414.62              -0.71   3458.80
# 2  1.132847e+11   1.834089e+10      1.00              -0.02      1.00
# 3  9.519750e+10   2.584634e+08    570.72              -0.77    576.65
# 4  7.275361e+10   7.965776e+08    156.74              -2.30    159.93
#
#                                             explorer
# 0                           https://blockchain.info/
# 1                              https://etherscan.io/
# 2             https://www.omniexplorer.info/asset/31
# 3  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4                       https://explorer.solana.com/

# %%
#Load the data into a PostgreSQL database

# %%
 #Database Credentials
db_username = 'postgres'
db_password = 1234
db_host = 'localhost'
db_port = 54321
db_name = 'crypto_data'

# %%
import psycopg2 #for connecting to PostgreSQL databases and executing queries
from sqlalchemy import create_engine #To efficiency manage and reuse database connections

# %%
#Establish a connection with sqlalchemy engine
engine=create_engine(f'postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# %%
#create a table
table_name='crypto_data'

#load the data into the table
df.to_sql(table_name,engine, if_exists='replace',index=False)

#Close the engine connection
engine.dispose()
